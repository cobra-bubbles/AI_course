# %%
import pandas as pd
import numpy as np

s = pd.Series(
    data=[10, "11,", [11, "12"], 14, "kakashka"],
    index=[2, "two", 2.1, -2.2, 2]
)
s
# Out:
#  2            10
#  two         11,
#  2.1    [11, 12]
# -2.2          14
# dtype: object

# %%
print(s[2.1])
# Out:
# [11, '12']

# %%
s[0:4]
# Out:
#  2            10
#  two         11,
#  2.1    [11, 12]
# -2.2          14
# dtype: object

# %%
s = pd.Series(
    data=['e', 'c', 'd', 'b', 'a', 'f'],
    index=['e', 'c', 'd', 'b', 'a', 'f']
)
s['a':'f']
# Out:
# a    a
# f    f
# dtype: object
